# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

os.listdir('/content/drive/MyDrive')
# Out:
# ['Colab Notebooks',
#  'Getting started.pdf',
#  'NGIR7BFL.DTA',
#  'IMG-20221023-WA0007.jpg',
#  'DAVTON CONTENT STATUS TRACKER.gsheet',
#  'My project ',
#  '24 Jan, 10.26 am\u200b.m4a',
#  'Customer churn PROJECT.gdoc',
#  'Neck Abscess and Management  (1).pdf',
#  'Neck Abscess and Management .gdoc',
#  'Neck Abscess and Management .pdf',
#  'Election results 1991-2023.gsheet']

# %%
import pandas as pd

file_path = "/content/drive/MyDrive/NGIR7BFL.DTA"  # adjust if needed

cols = ['v012','v025','v024','v106']

df = pd.read_stata(file_path, columns=cols)

df.head()
# Out:
#    v012   v025           v024       v106
# 0    40  urban  north central     higher
# 1    16  urban  north central  secondary
# 2    37  urban  north central     higher
# 3    27  urban  north central     higher
# 4    29  urban  north central  secondary

# %%
df.shape
# Out:
# (41821, 4)

# %%
df['v025'].value_counts()   # Urban vs Rural
df['v106'].value_counts()   # Education
df['v024'].value_counts()   # Region
# Out:
# v024
# north west       10129
# north central     7772
# north east        7639
# south west        5630
# south east        5571
# south south       5080
# Name: count, dtype: int64

# %%
df['v025'].value_counts()
# Out:
# v025
# rural    24837
# urban    16984
# Name: count, dtype: int64

# %%
df['v106'].value_counts()
# Out:
# v106
# secondary       16698
# no education    14398
# primary          6383
# higher           4342
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# Region
df['v024'].value_counts().plot(kind='bar')
plt.title("Distribution by Region")
plt.show()

# %%
# Urban vs Rural
df['v025'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title("Urban vs Rural Distribution")
plt.show()

# %%
# Education
df['v106'].value_counts().plot(kind='bar')
plt.title("Education Level Distribution")
plt.show()
